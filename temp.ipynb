# %%
import pandas as pd 
import requests
from bs4 import BeautifulSoup
import re
import time

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("temp.csv")
pd.set_option('display.max_rows', None)
#pandas.set_option('display.max_rows')


df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ','_')
df
# Out:
#                              country_or_territory  \
# 0                                               1
# 1                                       ARGENTINA
# 2                                       AUSTRALIA
# 3                                         AUSTRIA
# 4                                         BAHAMAS
# 5                                          CANADA
# 6                                        COLOMBIA
# 7   COLOMBIA (SAN ANDRES AND PROVIDENCIA ISLANDS)
# 8                                  CZECH REPUBLIC
# 9                                           EGYPT
# 10                                         GREECE
# 11                                         GUYANA
# 12                                       HONDURAS
# 13                                      HONG KONG
# 14                                        HUNGARY
# 15                                        ICELAND
# 16                      IRAN, ISLAMIC REPUBLIC OF
# 17                                         ISRAEL
# ...

# %%
df2 = df[df['annual_ncdc_computed_value_footnotes'] != 1]
df2 = df2[df2['jan_footnotes'] != 1]
df2 = df2[df2['feb_footnotes'] != 1]
df2 = df2[df2['mar_footnotes'] != 1]
df2 = df2[df2['apr_footnotes'] != 1]
df2 = df2[df2['may_footnotes'] != 1]
df2 = df2[df2['jun_footnotes'] != 1]
df2 = df2[df2['jul_footnotes'] != 1]
df2 = df2[df2['aug_footnotes'] != 1]
df2 = df2[df2['sep_footnotes'] != 1]
df2 = df2[df2['oct_footnotes'] != 1]
df2 = df2[df2['nov_footnotes'] != 1]
df2 = df2[df2['dec_footnotes'] != 1]
#df2 = df2[df2['annual_footnotes'] != 1]

df2
# Out:
#                                country_or_territory  \
# 0                                         ARGENTINA
# 2                                         ARGENTINA
# 4                                         ARGENTINA
# 6                                         ARGENTINA
# 8                                         ARGENTINA
# 10                                        ARGENTINA
# 12                                        ARGENTINA
# 14                                        ARGENTINA
# 16                                        ARGENTINA
# 18                                        ARGENTINA
# 20                                        ARGENTINA
# 22                                        ARGENTINA
# 24                                        ARGENTINA
# 26                                        ARGENTINA
# 28                                        ARGENTINA
# 30                                        ARGENTINA
# 32                                        ARGENTINA
# ...

# %%
# df2.group(by = 'country_or_territory')
# df2.first()

grouped = df2.groupby('country_or_territory').mean()
grouped
# Out:
#                                                wmo_station_number  \
# country_or_territory
# 1                                                             NaN
# ARGENTINA                                            87472.540984
# AUSTRALIA                                            94182.285714
# AUSTRIA                                              11233.000000
# BAHAMAS                                              78073.000000
# CANADA                                               71615.750000
# COLOMBIA                                             80186.764706
# COLOMBIA (SAN ANDRES AND PROVIDENCIA ISLANDS)        80001.000000
# CZECH REPUBLIC                                       11607.250000
# EGYPT                                                62398.300000
# GREECE                                               16698.818182
# GUYANA                                               81002.000000
# HONDURAS                                             78715.666667
# ...

# %%
striped.to_csv ('temp.csv', header=True)

# %%
grouped.sort_values('jan', ascending=False)
# Out:
#                                                     wmo_station_number  \
# country_or_territory
# CHAD                                                      64736.500000
# ERITREA                                                   63021.000000
# ARGENTINA                                                 87488.280000
# OMAN                                                      41276.500000
# URUGUAY                                                   86496.818182
# KENYA                                                     63711.400000
# THAILAND                                                  48430.647059
# MALI                                                      61256.722222
# AUSTRALIA (ANTARCTIC STATIONS)                            89567.500000
# MAURITIUS                                                 61989.000000
# SOUTH AFRICA                                              68578.307692
# AUSTRALIA                                                 94659.200000
# ...

# %%
# grouped.plot()

grouped = grouped[grouped.columns.drop(list(grouped.filter(regex='footnotes')))]
grouped = grouped[grouped.columns.drop(list(grouped.filter(regex='station')))]

grouped
# Out:
#                                                element-statistic_qualifier_code  \
# country_or_territory
# 1                                                                           NaN
# ARGENTINA                                                                   NaN
# AUSTRALIA                                                                  81.0
# AUSTRIA                                                                     NaN
# BAHAMAS                                                                     NaN
# CANADA                                                                      NaN
# COLOMBIA                                                                    NaN
# COLOMBIA (SAN ANDRES AND PROVIDENCIA ISLANDS)                               NaN
# CZECH REPUBLIC                                                              NaN
# EGYPT                                                                       NaN
# ...

# %%
striped = grouped[grouped.columns.drop(list(grouped.filter(regex='annual')))]

striped
# Out:
#                                                element-statistic_qualifier_code  \
# country_or_territory
# 1                                                                           NaN
# ARGENTINA                                                                   NaN
# AUSTRALIA                                                                  81.0
# AUSTRIA                                                                     NaN
# BAHAMAS                                                                     NaN
# CANADA                                                                      NaN
# COLOMBIA                                                                    NaN
# COLOMBIA (SAN ANDRES AND PROVIDENCIA ISLANDS)                               NaN
# CZECH REPUBLIC                                                              NaN
# EGYPT                                                                       NaN
# ...

# %%
#striped[~striped['country_or_territory'].str.contains("1")]
striped = striped.iloc[1: , :]
striped
# Out:
#                                                            jan         feb  \
# country_or_territory
# AFGHANISTAN, ISLAMIC STATE OF                       160.870000  154.670000
# ARGENTINA                                           283.836000  245.728000
# ARMENIA                                              94.500000  106.000000
# AUSTRALIA                                           258.230000  223.626667
# AUSTRALIA (ANTARCTIC STATIONS)                      265.050000  191.800000
# AUSTRIA                                              73.285714   98.714286
# AZERBAIJAN                                           98.622222   95.444444
# BAHAMAS                                             220.100000  212.800000
# BAHRAIN                                             226.300000  221.200000
# BELARUS                                              48.250000   68.500000
# BELGIUM                                              48.600000   77.500000
# ...
